# %%
class BankAccount
    total_accounts = 0

    def _init_(self, holder, name, initial_balance):
        self.holder_name =
    holder_name

    BankAccount.total_accounts = +1

number
    self.__account_number = 
BankAccount.total_accounts

    if initial_balance >= 0:
        self.__balance = 
initial_balance
    else:
        self.__balance = 0

    def get_balance(self):
        return self.__balance
    
    def deposit(self, amount):
        if amount > 0: 
            self.__balance += amount
        else:
            print("Invalid deposit amount")

    def withdraw(self, amount):
        if amount > 0 and
self.__balance >=amount:
        self.__balance -= amount
        else:
            print("Transaction denied")
# Out:
# 2026-02-05

# %%
class SavingsAccount(BankAccount):
    def _init_(self, holder_name, initial_balance, interest_rate):
        super()._init_(holder_name, initial_balance)
        self.interest_rate = interest_rate
    
    def apply_interest(self):
        interest = self.get_balanced()
    self. interest_rate = interest_rate
        self.deposit(interest)

# %%
class VIPAccount(BankAccount):
    def _init_(self, holder_name, initial_balance, overdraft_limit):
        super()._init_(holder_name, initial_balance)
        self.overdraft_limit = overdraft_limit

    def withdraw(self, amount):
        if amount > 0:
            if self.get_balance() - amount >= self.overdraft_limit:
                balance via deposit logic
self.__BankAccount__balance -= amount
        else:
            print("Transaction denied")
        else:
            print("Invalid withdrawal amount")
